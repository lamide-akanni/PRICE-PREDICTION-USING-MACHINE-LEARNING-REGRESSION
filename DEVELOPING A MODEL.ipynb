# %% [markdown]
# **DEVELOPING A MODEL**
#
#
# Objective(s) -
# Develop prediction models

# %% [markdown]
# In this NOTE have models that will predict the price of the car using the variables or features. P.S;This is just an estimate but should give us an objective idea of how much the car should cost.

# %% [markdown]
# **QUESTIONS**?
#
# Do I know if the dealer is offering fair value for my trade-in?
#
# Do I know if I put a fair value on my car?
#
# This Model Development will help to predict future observations from the data we have.
#
# A model will help us understand the exact relationship between different variables and how these variables are used to predict the result.

# %% [markdown]
# That dataset is originally from the UCI Machine Learning Repository:
#
# UCI Automobile Dataset:
#
# 🔗 https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data

# %% [markdown]
# **Setup**

# %% [markdown]
# Import libraries:

# %%
#install specific version of libraries used in lab
#! mamba install pandas==1.3.3-y
#! mamba install numpy=1.21.2-y
#! mamba install sklearn=0.20.1-y

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load dataset and store in dataframe in df:

# %%
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"

columns = [
    "symboling", "normalized-losses", "make", "fuel-type", "aspiration",
    "num-of-doors", "body-style", "drive-wheels", "engine-location",
    "wheel-base", "length", "width", "height", "curb-weight", "engine-type",
    "num-of-cylinders", "engine-size", "fuel-system", "bore", "stroke",
    "compression-ratio", "horsepower", "peak-rpm", "city-mpg", "highway-mpg", "price"
]

df = pd.read_csv(url, names=columns)
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# **Linear Regression and Multiple Linear Regression**

# %% [markdown]
# **Linear Regression**

# %% [markdown]
# **Simple Linear Regression**
#
# Simple Linear Regression is a method to help us understand the relationship between two variables:
#
# The predictor/independent variable (X)
# The response/dependent variable (that we want to predict)(Y)
# The result of Linear Regression is a linear function that predicts the response (dependent) variable as a function of the predictor (independent) variable.

# %% [markdown]
# $$ Linear Function:
#  Y - Response \ Variable\\\\\\\
#  X - Predictor \ Variables
# $$

# %% [markdown]
# $$
# Yhat = a + b  X
# $$
#
# a - refers to the intercept of the regression line, in other words: the value of Y when X is 0
#
# b - refers to the slope of the regression line, in other words: the value with which Y changes when X increases by 1 unit

# %% [markdown]
# <h4>Let's load the modules for linear regression:</h4>

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# <h4>Create the linear regression object:</h4>

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %% [markdown]
# <h4>How could "highway-mpg" help us predict car price?</h4>

# %% [markdown]
# highway-mpg to predict car price.
# Using simple linear regression, we will create a linear function with "highway-mpg" as the predictor variable and the "price" as the response variable.

# %%
X = df[['highway-mpg']]
Y = df['price']

# %% [markdown]
# Fit the linear model using highway-mpg:

# %%
#lm.fit(X,Y)

# %% [markdown]
# dataset contains ? characters, and the regression model cannot process strings.
#
# scikit-learn requires pure numeric values.

# %%
import numpy as np

df.replace("?", np.nan, inplace=True)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# covvert the column used 

df["highway-mpg"] = df["highway-mpg"].astype(float)
df["price"] = df["price"].astype(float)

# %%
#if mssing value remain, drop them;

df = df.dropna(subset=["highway-mpg","price"])

# %%
#fit model again

X = df[["highway-mpg"]]
Y = df["price"]

lm.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# output a prediction:

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %% [markdown]
# <h4>What is the value of the intercept (a)?</h4>

# %%
lm.intercept_
# Out:
# np.float64(38423.3058581574)

# %% [markdown]
# <h4>What is the value of the slope (b)?</h4>

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# <h3>What is the final estimated linear model we get?</h3>

# %% [markdown]
# ## Yhat = a + b  X

# %% [markdown]
# Price = 38423.31 - 821.73 x (highway-mpg)

# %% [markdown]
# **Interpretation**

# %% [markdown]
# If highway-mpg = 0, predicted price is $38,423
#
# Each 1 MPG increase reduces price by about $821.
#
# Cars with better fuel efficiency tend to be cheaper.
#
# Caveat: highway-mpg = 0 is unrealistic; the intercept is not meaningful in practice, just mathematically necessary for the line.

# %% [markdown]
# <b>Create a  (another) linear regression object called "lm1".</b>
# </div>

# %%
#from sklearn.linear_model import LinearRegression

lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %% [markdown]
# Train the model using "engine-size" as the independent variable and "price" as the dependent variable

# %%
lm1.fit(df[['engine-size']], df[['price']])
lm1

#fit model again

X = df[["engine-size"]]
Y = df["price"]

lm.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# <b>Find the slope and intercept of the model.</b>
# </div>

# %% [markdown]
# <h4>Slope</h4>

# %%
Yhat=lm1.predict(X)
Yhat[0:9]
# Out:
# array([[13728.4631336 ],
#        [13728.4631336 ],
#        [17399.38347881],
#        [10224.40280408],
#        [14729.62322775],
#        [14729.62322775],
#        [14729.62322775],
#        [14729.62322775],
#        [13895.32314929]])

# %% [markdown]
# <h4>Intercept (a)?</h4>

# %%
lm1.intercept_
# Out:
# array([-7963.33890628])

# %% [markdown]
# <h4>Slope (b)?</h4>

# %%
lm1.coef_
# Out:
# array([[166.86001569]])

# %% [markdown]
#  <h3>What is the final estimated linear model(lm1) we get?</h3>

# %% [markdown]
# ## Yhat = a + b  X

# %% [markdown]
# Price = -7963.39 + 166.86 x (engine-size)

# %% [markdown]
# **Interpretation 2**

# %% [markdown]
# Every additional unit of engine size increases predicted price by $166.86.
#
# Intercept = -7963.39 → if engine-size = 0, predicted price is negative.
#
# Caveat: Negative intercept is not realistic (a car cannot have 0 engine size), The slope is just an indicator of  bigger engines → higher prices.

# %% [markdown]
# <h4>Multiple Linear Regression</h4>

# %% [markdown]
# What if we want to predict car price using more than one variable?
#
# If we want to use more variables in our model to predict car price, we can use Multiple Linear Regression. Multiple Linear Regression is very similar to Simple Linear Regression, but this method is used to explain the relationship between one continuous response (dependent) variable and two or more predictor (independent) variables. Most of the real-world regression models involve multiple predictors. We will illustrate the structure by using four predictor variables, but these results can generalize to any integer:

# %% [markdown]
# $$
# Y: Response \ Variable\\\\\\
# X_1 :Predictor\ Variable \ 1\\
# X_2: Predictor\ Variable \ 2\\
# X_3: Predictor\ Variable \ 3\\
# X_4: Predictor\ Variable \ 4\\
# $$

# %% [markdown]
# $$
# a: intercept\\\\\\
# b_1 :coefficients \ of\ Variable \ 1\\
# b_2: coefficients \ of\ Variable \ 2\\
# b_3: coefficients \ of\ Variable \ 3\\
# b_4: coefficients \ of\ Variable \ 4\\
# $$

# %% [markdown]
# The equation is given by:

# %% [markdown]
# $$
# Yhat = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# $$

# %% [markdown]
# From the above section;  we know that other **good predictors of price** could be:
#
# - Horsepower
#
# - Curb-weight
#
# - Engine-size
#
# - Highway-mpg
#
# **Let's develop a model using these variables as the predictor variables.**

# %%
#Inspect the data
df[['horsepower','curb-weight','engine-size','highway-mpg','price']].isnull().sum()
# Out:
# horsepower     2
# curb-weight    0
# engine-size    0
# highway-mpg    0
# price          0
# dtype: int64

# %%
#Replace the missing horsepower values with the mean horsepower
#Replace the "?" values with NaN
#Convert the column (obeject or string) to numeric (float)
#Fill the missing values with the mean


import numpy as np

df['horsepower'] = df['horsepower'].replace('?', np.nan)

df['horsepower'] = df['horsepower'].astype(float)

df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mean())

# %% [markdown]
# <h4>Create the multi regression object:</h4>

# %%
lm_multi = LinearRegression()
lm_multi
# Out:
# LinearRegression()

# %%
#Fit the multi regression model

Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
lm_multi.fit(Z, df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# <h4>What is the value of the intercept(a)?</h4>

# %%
lm_multi.intercept_
# Out:
# np.float64(-15824.03820823447)

# %% [markdown]
# <h4>What are the values of the coefficients (b1, b2, b3, b4)?</h4>

# %%
lm_multi.coef_
# Out:
# array([53.61042729,  4.70886444, 81.47225667, 36.39637823])

# %% [markdown]
# <h4>Multiple regression equation model  is </h4>

# %% [markdown]
# Price = −15824.04+53.61(Horsepower)+4.71(CurbWeight)+81.47(EngineSize)+36.40(HighwayMPG)

# %% [markdown]
# **Interpretation 3**

# %% [markdown]
# **Intercept** If horsepower = 0, curb-weight = 0, engine-size = 0, and highway-mpg = 0, the predicted price is −$15,824.04.
# Caveat: This is not meaningful in reality because a car cannot have all those values equal to zero. The intercept is just the mathematical starting point needed for the regression equation
#
# **Horsepower** Every 1 unit increase in horsepower increases the predicted price by about $53.61, assuming curb-weight, engine-size, and highway-mpg remain constant.
# p.s; Cars with more powerful engines tend to be more expensive
#
# **Curb Weight** Every 1 unit increase in curb-weight increases the predicted price by about $4.71, assuming horsepower, engine-size, and highway-mpg stay constant. Heavier cars tend to be slightly more expensive, though the effect is relatively small compared with other variables.
#
# **Engine Size** Every 1 unit increase in engine-size increases the predicted price by about $81.47, assuming horsepower, curb-weight, and highway-mpg remain constant. We should know that Larger engines generally increase car price, reflecting higher performance or higher-end models.
#
# **Highway MPG** Every 1 unit increase in highway-mpg increases the predicted price by about $36.40, assuming horsepower, curb-weight, and engine-size stay constant. In this model, cars with better highway fuel efficiency tend to have slightly higher predicted prices, although this may reflect relationships between efficiency, technology, and vehicle class rather than a direct causal effect.
#
# **Important caveat** Variables like horsepower, engine-size, and curb-weight are strongly related. Because of this multicollinearity, the individual coefficients may not perfectly represent real-world causal effects. The model still predicts price, but interpretation of each coefficient should be done carefully.

# %% [markdown]
#  <h3>Build another regression model using two predictors, NormalizedLosses and HighwayMPG   </h3>

# %%
lm_multi2 = LinearRegression()

# %%
#Check for missing vaules

df[['normalized-losses', 'highway-mpg']].isnull().sum()
# Out:
# normalized-losses    37
# highway-mpg           0
# dtype: int64

# %%
#Fill the missing values with the mean

df['normalized-losses'] = df['normalized-losses'].replace('?', np.nan)

df['normalized-losses'] = df['normalized-losses'].astype(float)

df['normalized-losses'] = df['normalized-losses'].fillna(df['normalized-losses'].mean())

# %%
lm_multi2 = LinearRegression()
X = df[['normalized-losses', 'highway-mpg']]
y = df['price']
lm_multi2.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# <h4>What is the value of the intercept(a)?</h4>

# %%
lm_multi2.intercept_
# Out:
# np.float64(38201.31327245727)

# %% [markdown]
# <h4>What are the values of the coefficients?</h4>

# %%
lm_multi2.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %% [markdown]
# **Interpretation 4**

# %% [markdown]
# **Intercept** If normalized-losses = 0 and highway-mpg = 0, predicted price is $38,201.31.
# This is not realistic, as cars cannot have 0 MPG or 0 normalized-losses. The intercept is just mathematically necessary.
#
# **Normalized-Losses** Coefficient = 1.50 Every 1 unit increase in normalized-losses increases predicted price by $1.50, assuming highway-mpg stays constant.
#
# Effect is very small; this variable is a weak predictor of price.
#
# **HighwayMPG** Coefficient = -820.45 Every 1 MPG increase in highway fuel efficiency decreases predicted price by $820.45, assuming normalized-losses stays constant.
#
# This is more of a correlation than a causal effect; cars with very high MPG are usually smaller or economy models, which drives price down.

# %% [markdown]
# <h2>Model Evaluation Using Visualization</h2>

# %% [markdown]
# How do we evaluate our models and choose the best one? One way to do this is by using a visualization.
#
# Import the visualization package, seaborn:

# %%
# import the visualization package: seaborn
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h3>Regression Plot</h3>

# %% [markdown]
# When it comes to simple linear regression, an excellent way to visualize the fit of our model is by using regression plots.
#
# This plot will show a combination of a scattered data points (a scatterplot), as well as the fitted linear regression line going through the data. This will give us a reasonable estimate of the relationship between the two variables, the strength of the correlation, as well as the direction (positive or negative correlation).

# %% [markdown]
# visualize highway-mpg as potential predictor variable of price:

# %%
width = 8
height = 6
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48193.77068972463)

# %% [markdown]
# We can see from this plot that price is negatively correlated to highway-mpg since the regression slope is negative.

# %% [markdown]
# One thing to keep in mind when looking at a regression plot is to pay attention to how scattered the data points are around the regression line. This will give you a good indication of the variance of the data and whether a linear model would be the best fit or not. If the data is too far off from the line, this linear model might not be the best model for this data.

# %% [markdown]
# visualize peak-rpm as potential predictor variable of price:

# %%
df['peak-rpm'] = pd.to_numeric(df['peak-rpm'], errors='coerce')
df['price'] = pd.to_numeric(df['price'], errors='coerce')

df_clean = df.dropna(subset=['peak-rpm', 'price'])

width = 8
height = 6
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df_clean)
plt.ylim(0,)
plt.show()

# %% [markdown]
# The points for "peak-rpm" have more spread around the predicted line and it is much harder to determine if the points are decreasing or increasing as the "peak-rpm" increases.

# %% [markdown]
# <b>"peak-rpm" or "highway-mpg" more strongly correlated with "price"? Use the method  ".corr()" to verify answer.</b>
# </div>

# %%
df[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058606 -0.101649
# highway-mpg -0.058606     1.000000 -0.704692
# price       -0.101649    -0.704692  1.000000

# %% [markdown]
#  The variable "highway-mpg" has a stronger correlation with "price", it is approximate -0.704692  compared to "peak-rpm" which is approximate -0.101616.

# %% [markdown]
# <h3>Residual Plot</h3>
#
# <p>A good way to visualize the variance of the data is to use a residual plot.</p>
#
# <p>What is a <b>residual</b>?</p>
#
# <p>The difference between the observed value (y) and the predicted value (Yhat) is called the residual (e). When we look at a regression plot, the residual is the distance from the data point to the fitted regression line.</p>
#
# <p>So what is a <b>residual plot</b>?</p>
#
# <p>A residual plot is a graph that shows the residuals on the vertical y-axis and the independent variable on the horizontal x-axis.</p>
#
# <p>What do we pay attention to when looking at a residual plot?</p>
#
# <p>We look at the spread of the residuals:</p>
#
# <p>- If the points in a residual plot are <b>randomly spread out around the x-axis</b>, then a <b>linear model is appropriate</b> for the data.
#
# Why is that? Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data.</p>

# %%
width = 7
height = 6
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-mpg'], y=df['price'])
plt.show()

# %% [markdown]
# We can see from this residual plot that the residuals are not randomly spread around the x-axis, leading us to believe that maybe a non-linear model is more appropriate for this data.

# %% [markdown]
# <h3>Multiple Linear Regression</h3>

# %% [markdown]
# How do we visualize a model for Multiple Linear Regression? This gets a bit more complicated because you can't visualize it with regression or residual plot.
#
# One way to look at the fit of the model is by looking at the distribution plot. We can look at the distribution of the fitted values that result from the model and compare it to the distribution of the actual values.

# %% [markdown]
# First, let's make a prediction:

# %%
Y_hat = lm_multi.predict(Z)  # lm_multi is trained on 4 columns

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# C:\Users\lamid\AppData\Local\Temp\ipykernel_11348\4196657742.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
# C:\Users\lamid\AppData\Local\Temp\ipykernel_11348\4196657742.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# We can see that the fitted values are reasonably close to the actual values since the two distributions overlap a bit. However, there is definitely some room for improvement.

# %% [markdown]
# <h2>Polynomial Regression and Pipelines</h2>

# %% [markdown]
# Polynomial regression is a particular case of the general linear regression model or multiple linear regression models.
#
# We get non-linear relationships by squaring or setting higher-order terms of the predictor variables.
#
# There are different orders of polynomial regression:

# %% [markdown]
# <center><b>Quadratic - 2nd Order</b></center>
# $$
# Yhat = a + b_1 X +b_2 X^2
# $$
#
#
# <center><b>Cubic - 3rd Order</b></center>
# $$
# Yhat = a + b_1 X +b_2 X^2 +b_3 X^3\\\\\\
# $$
#
#
# <center><b>Higher-Order</b>:</center>
# $$
# Y = a + b_1 X +b_2 X^2 +b_3 X^3 ....\\
# $$

# %% [markdown]
# We saw earlier that a linear model did not provide the best fit while using "highway-mpg" as the predictor variable. Let's see if we can try fitting a polynomial model to the data instead.

# %%
#use the following function to plot the data:

def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %% [markdown]
# Let's get the variables:

# %%
x = df['highway-mpg']
y = df['price']

# %% [markdown]
# Let's fit the polynomial using the function polyfit, then use the function poly1d to display the polynomial function.

# %%
# Here we use a polynomial of the 3rd order (cubic) 
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %% [markdown]
# Let's plot the function:

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %%
np.polyfit(x, y, 3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %% [markdown]
# We can already see from plotting that this polynomial model performs better than the linear model. This is because the generated polynomial function "hits" more of the data points.

# %% [markdown]
# <b>Create 11 order polynomial model with the variables x and y from above.</b>
# </div>

# %%
# Here we use a polynomial of the 11rd order (cubic) 
f1 = np.polyfit(x, y, 11)
p1 = np.poly1d(f1)
print(p1)
PlotPolly(p1,x,y, 'Highway MPG')
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %% [markdown]
# The analytical expression for Multivariate Polynomial function gets complicated. For example, the expression for a second-order (degree=2) polynomial with two variables is given by:

# %% [markdown]
# $$
# Yhat = a + b_1 X_1 +b_2 X_2 +b_3 X_1 X_2+b_4 X_1^2+b_5 X_2^2
# $$

# %% [markdown]
# We can perform a polynomial transform on multiple features. First, we import the module:

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# We create a PolynomialFeatures object of degree 2:

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
Z_pr=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (201, 4)

# %% [markdown]
# In the original data, there are 201 samples and 4 features.

# %%
#After the transformation, there are 201 samples and 15 features.
Z_pr.shape
# Out:
# (201, 15)

# %% [markdown]
# <h2>Pipeline</h2>

# %% [markdown]
# Data Pipelines simplify the steps of processing the data. We use the module Pipeline to create a pipeline. We also use StandardScaler as a step in our pipeline.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# We create the pipeline by creating a list of tuples including the name of the model or estimator and its corresponding constructor.

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %% [markdown]
# We input the list as an argument to the pipeline constructor:

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# First, we convert the data type Z to type float to avoid conversion warnings that may appear as a result of StandardScaler taking float inputs.
#
# Then, we can normalize the data,  perform a transform and fit the model simultaneously.

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# <b>Create a pipeline that standardizes the data, then produce a prediction using a linear regression model using the features Z and target y.</b>
# </div>

# %%
Input=[('scale',StandardScaler()),('model',LinearRegression())]

pipe=Pipeline(Input)

pipe.fit(Z,y)

ypipe=pipe.predict(Z)
ypipe[0:10]
# Out:
# array([13699.00138847, 13699.00138847, 19055.18075089, 10621.20889105,
#        15519.94133137, 13868.36830279, 15455.25561838, 15973.23070656,
#        17613.77045652, 10722.84396625])

# %% [markdown]
# <h2> Measures for Evaluation</h2>

# %% [markdown]
# When evaluating our models, not only do we want to visualize the results, but we also want a quantitative measure to determine how accurate the model is.
#
# Two very important measures that are often used in Statistics to determine the accuracy of a model are:
#
# R^2 / R-squared
#
# Mean Squared Error (MSE)
#
#
# R squared, also known as the coefficient of determination, is a measure to indicate how close the data is to the fitted regression line.
#
# The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model.
#
# Mean Squared Error (MSE)
#
# The Mean Squared Error measures the average of the squares of errors. That is, the difference between actual value (y) and the estimated value (ŷ).

# %% [markdown]
# <h3>Model 1: Simple Linear Regression</h3>

# %%
#Calculating R^2
#highway_mpg_fit
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.4966263556974878

# %% [markdown]
# We can say that ~49.659% of the variation of the price is explained by this simple linear model "horsepower_fit".

# %%
#Calculationg MSE
#We can predict the output i.e., "yhat" using the predict method, where X is the input variable:

Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16231.78938339 16231.78938339 17052.24372355 13833.33798916]

# %% [markdown]
# Let's import the function <b>mean_squared_error</b> from the module <b>metrics</b>:

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# can compare the predicted results with the actual results:

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31632832.975589428

# %% [markdown]
# <h3>Model 2: Multiple Linear Regression</h3>

# %% [markdown]
# Let's calculate the R^2:

# %%
#Let's calculate the R^2:
# fit the model 
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))
# Out:
# The R-square is:  0.8094130135602673

# %% [markdown]
# We can say that ~80.896 % of the variation of price is explained by this multiple linear regression "multi_fit".

# %% [markdown]
# Let's calculate the MSE.

# %% [markdown]
# We produce a prediction:

# %%
Y_predict_multifit = lm.predict(Z)

# %% [markdown]
# We compare the predicted results with the actual results

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  11976801.681229586

# %% [markdown]
# <h3>Model 3: Polynomial Fit</h3>

# %% [markdown]
# Let's calculate the R^2.

# %% [markdown]
# Let’s import the function r2_score from the module metrics as we are using a different function.

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# We apply the function to get the value of R^2:

# %%
r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.674194666390652

# %% [markdown]
# We can say that ~67.419 % of the variation of price is explained by this polynomial fit.

# %% [markdown]
# Let's calculate the MSE

# %%
mean_squared_error(df['price'], p(x))
# Out:
# 20474146.426361218

# %% [markdown]
# <h2> Prediction and Decision Making</h2>
# <h3>Prediction</h3>
#
# <p>From the above npote we trained the model using the method <b>fit</b>. Now we will use the method <b>predict</b> to produce a prediction. Lets import <b>pyplot</b> for plotting; we will also be using some functions from numpy.</p>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# Create a new input:

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)

# %% [markdown]
# Fit the model:

# %%
lm = LinearRegression()
lm.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# Produce a prediction:

# %%
# Step 1: Prepare predictors (X) and response (Y)
X_multi = df[['normalized-losses', 'highway-mpg']]  # 2 predictors
Y = df['price']

# %%
# Step 3: Prepare new input for predictions
# Example: normalized-losses and highway-mpg values
new_input_multi = np.array([
    [100, 20],
    [150, 25],
    [200, 30],
    [250, 35],
    [300, 40]
])  # shape (5,2) → 5 samples, 2 features

# %%
# Step 4: Make predictions
yhat_multi = lm_multi2.predict(new_input_multi)
print("Predicted prices for first 5 inputs:", yhat_multi)
# Out:
# Predicted prices for first 5 inputs: [21942.01605553 17914.63914789 13887.26224024  9859.8853326
#   5832.50842495]
# C:\Users\lamid\AppData\Local\Programs\Python\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Step 5: Visualize predicted vs actual using distribution plot
plt.figure(figsize=(8,5))
sns.histplot(Y, color='red', label='Actual Price', kde=True)
sns.histplot(yhat_multi, color='blue', label='Predicted Price', kde=True)
plt.title('Predicted vs Actual Price (Multi-Variable Model)')
plt.xlabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# <h3>Decision Making: Determining a Good Model Fit</h3>

# %% [markdown]
# Now that we have visualized the different models, and generated the R-squared and MSE values for the fits, how do we determine a good model fit?
#
# What is a good R-squared value?
#
# **When comparing models, the model with the higher R-squared value is a better fit for the data.**
#
# What is a good MSE?
#
# **When comparing models, the model with the smallest MSE value is a better fit for the data.**
#
# Let's take a look at the values for the different models.
#
# **Simple Linear Regression:** Using Highway-mpg as a Predictor Variable of Price.
#
# R-squared: 0.49659118843391759
#
# MSE: 3.16 x10^7
#
# **Multiple Linear Regression:** Using Horsepower, Curb-weight, Engine-size, and Highway-mpg as Predictor Variables of Price.
#
# R-squared: 0.80896354913783497
#
# MSE: 1.2 x10^7
#
# **Polynomial Fit:** Using Highway-mpg as a Predictor Variable of Price.
#
# R-squared: 0.6741946663906514
#
# MSE: 2.05 x 10^7

# %% [markdown]
# <h3>Simple Linear Regression Model (SLR) vs Multiple Linear Regression Model (MLR)</h3>

# %% [markdown]
# Usually, the more variables you have, the better your model is at predicting, but this is not always true. Sometimes you may not have enough data, you may run into numerical problems, or many of the variables may not be useful and even act as noise. As a result, you should always check the MSE and R^2.
#
# In order to compare the results of the MLR vs SLR models, we look at a combination of both the R-squared and MSE to make the best conclusion about the fit of the model.
#
# MSE: The MSE of SLR is 3.16x10^7 while MLR has an MSE of 1.2 x10^7. The MSE of MLR is much smaller.
# R-squared: In this case, we can also see that there is a big difference between the R-squared of the SLR and the R-squared of the MLR. The R-squared for the SLR (~0.497) is very small compared to the R-squared for the MLR (~0.809).
# This R-squared in combination with the MSE show that MLR seems like the better model fit in this case compared to SLR.

# %% [markdown]
# <h3>Simple Linear Model (SLR) vs. Polynomial Fit</h3>

# %% [markdown]
# <ul>
#     <li><b>MSE</b>: We can see that Polynomial Fit brought down the MSE, since this MSE is smaller than the one from the SLR.</li>
#     <li><b>R-squared</b>: The R-squared for the Polynomial Fit is larger than the R-squared for the SLR, so the Polynomial Fit also brought up the R-squared quite a bit.</li>
# </ul>
# <p>Since the Polynomial Fit resulted in a lower MSE and a higher R-squared, we can conclude that this was a better fit model than the simple linear regression for predicting "price" with "highway-mpg" as a predictor variable.</p>

# %% [markdown]
# <h3>Multiple Linear Regression (MLR) vs. Polynomial Fit</h3>

# %% [markdown]
# <ul>
#     <li><b>MSE</b>: The MSE for the MLR is smaller than the MSE for the Polynomial Fit.</li>
#     <li><b>R-squared</b>: The R-squared for the MLR is also much larger than for the Polynomial Fit.</li>
# </ul>

# %% [markdown]
# <h2>Conclusion</h2>

# %% [markdown]
# <p>Comparing these three models, we conclude that <b>the MLR model is the best model</b> to be able to predict price from our dataset. This result makes sense since we have 27 variables in total and we know that more than one of those variables are potential predictors of the final car price.</p>
